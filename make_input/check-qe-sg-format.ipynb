# %%
# %load_ext autoreload
# %autoreload 2

import spglib as spg
import ase
from ase.visualize import view
# the FIRE optimizer seems much better than the BFGS
from ase.optimize import BFGS, FIRE
from ase.calculators.lj import LennardJones
import ase.spacegroup as aspg
import numpy as np
import pandas as pd
from collections import Iterable
import pickle as pck

import sys, os
# add to PYTHONPATH
modulepath = '/home/musil/Dropbox/Felix_work/qmat/spglib-test/'
#modulepath = '/Users/iMac/Dropbox/Felix_work/qmat/spglib-test/'
if modulepath not in sys.path:
    sys.path.insert(0,modulepath)

from genGeneralSites import GenCrystalStructures
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-7a34bab74f0c> in <module>()
#      21     sys.path.insert(0,modulepath)
#      22
# ---> 23 from genGeneralSites import GenCrystalStructures
#
# ImportError: No module named genGeneralSites

# %%
from genGeneralSites import GenCrystalStructures

# %% [markdown]
# ## Functions to print blocks of QE inputs

# %%
def makeCard(cardDict,cardKeys=None,optionKey='unit',T=False, endl = ' \n',eq = ' = ',stl = '  '):
    """Transform a Card block in dict form into a string."""
    from itertools import izip_longest
    from  tabulate import tabulate
    cardStr = ''
    if cardKeys is None:
        keys =  cardDict.keys()
        keys.remove(optionKey)
        cardKeys = cardDict[keys[0]]
        
    if optionKey in cardDict.keys():
        keys =  cardDict.keys()
        keys.remove(optionKey)
        for key in keys:
            cardStr += key + stl
        cardStr += cardDict[optionKey] + endl

        for key,val in cardDict.items():
            if isinstance(val, dict):
                l = [val[cardKey] for cardKey in cardKeys] 
                ll = map(list, izip_longest(*l)) if T else l
                cardStr += stl + tabulate(ll, tablefmt="plain").replace('[','').replace(']','').replace(',','').replace('\n',endl+stl) + endl
        
        return cardStr
    else:
        print 'cardDict has no key called: {} (optionKey)'.format(optionKey)
def makeNamelist(namelistName,namelistDict,namelistKeys=None, endl = ' \n',eq = ' = ',stl = '  '):
    """Transform a Name List block in dict form into a string."""
    if namelistKeys is None:
        namelistKeys = namelistDict.keys()
    namelistStr = namelistName + endl
    for key in namelistKeys:
        namelistStr += stl + key + eq + namelistDict[key] + endl
    namelistStr += '/' + endl
    return namelistStr

# %% [markdown]
# # Input file generator function

# %%
def SG2ibrav(spaceGroupIdx,SGTable):
    ibrav = None
    sgInfo = SGTable[SGTable['Table No.'] == spaceGroupIdx]
    bravaisLattice = sgInfo['Crystal System'].values[0].encode('utf-8') + ' ' + sgInfo['Full notation'].values[0][0].encode('utf-8')
    bravaisLattice2ibrav = {'cubic P':1,'cubic F':2,'cubic I':3,'hexagonal P':4,'trigonal P':4,'trigonal R':5,'tetragonal P':6,'tetragonal I':7,
                            'orthorhombic P':8,'orthorhombic A':9,'orthorhombic B':9,'orthorhombic C':9,'orthorhombic F':10,'orthorhombic I':11,
                            'monoclinic P':12,'monoclinic A':13,'monoclinic B':13,'monoclinic C':13, 'triclinic P':14}
    ibrav = bravaisLattice2ibrav[bravaisLattice]
   
    return ibrav

def SG2wyckoff(spaceGroupIdx,wyckTable):
    highestMultiplicitySite = wyckTable[spaceGroupIdx].ix[0,:]
    return str(highestMultiplicitySite['Multiplicity']) + highestMultiplicitySite['Wyckoff letter']

def SG2Postion(spaceGroupIdx,crystals):
    generalPosition = crystals[spaceGroupIdx][0].get_scaled_positions()[0]
    return generalPosition

def SG2cellParam(spaceGroupIdx,crystals):
    cellParam = crystals[spaceGroupIdx][0].get_cell_lengths_and_angles()
    return cellParam

def makeQEInnput(crystals,WyckTable,SGTable,ElemTable,
                 zatom = 14,rhocutoff = 20 * 4,wfccutoff = 20,kpt = [2,2,2],kpt_offset = [0,0,0]):
    inputDic = {}
    
    elemInfo = ElemTable[ElemTable['z'] == zatom]
    species = [elemInfo['sym'].values[0],]*1
    mass = [elemInfo['mass'].values[0]] # in atomic unit
    PP = ['Si.pbe-n-rrkjus_psl.1.0.0.UPF']
    nvalence = elemInfo['val'].values[0]
    
    for SpaceGroupIdx in crystals:
        wyck = [SG2wyckoff(SpaceGroupIdx,WyckTable)]
        positions = [SG2Postion(SpaceGroupIdx,crystals)]
        cellParam = SG2cellParam(SpaceGroupIdx,crystals)
        ibrav = SG2ibrav(SpaceGroupIdx,SGTable)
        multipicity = WyckTable[SpaceGroupIdx]['Multiplicity'][0]

        if int(0.2*multipicity*nvalence/2.) > 4:
            nbnd = int(multipicity*nvalence/2.+int(0.2*multipicity*nvalence/2.))
        else:
            nbnd = int(multipicity*nvalence/2.+4)
        
        # define name list of QE
        control = {'calculation' : '"scf"',
                  'outdir' : '"./out/"',
                  'prefix' : '"qe"',
                  'pseudo_dir' : '"./pseudo"',
                  'restart_mode' : '"from_scratch"',
                  'verbosity' : '"high"',
                  'wf_collect' : '.false.',
            }
        controlKeys = ['calculation','outdir','prefix','pseudo_dir', 'restart_mode','verbosity' ,'wf_collect']
        system = {
                  'ecutrho' :   '{:.5f}'.format(rhocutoff),
                  'ecutwfc' :   '{:.5f}'.format(wfccutoff),
                  'ibrav' : str(ibrav),
                  'nat' : str(1),
                  'nbnd' : str(nbnd),
                  'ntyp' : str(1),
                  'occupations' : '"smearing"',
                  'smearing' : '"cold"',
                  'degauss' :   '1.0000000000d-02',
                  'space_group' : str(SpaceGroupIdx),
                  'A' : str(cellParam[0]),
                  'B' : str(cellParam[1]),
                  'C' : str(cellParam[2]),
                  'cosAB' : '{:.5f}'.format(np.cos(cellParam[5]*np.pi/180.)),
                  'cosAC' : '{:.5f}'.format(np.cos(cellParam[4]*np.pi/180.)),
                  'cosBC' : '{:.5f}'.format(np.cos(cellParam[3]*np.pi/180.)),
            }
        syskeys = [ 'ecutrho','ecutwfc','ibrav', 'nat','nbnd','ntyp' ,
                   'occupations', 'smearing','degauss','space_group','A','B' ,'C', 'cosAB', 'cosAC', 'cosBC' ]
        electrons = {'conv_thr':'1.0000000000d-06'}

        # define cards of QE
        optionkey = 'unit'
        atomic_sp = {'ATOMIC_SPECIES':{'species':np.unique(species), 'mass':mass,'PP':PP},'unit':''}
        atspkeys = ['species','mass','PP']
        atomic_pos = {'ATOMIC_POSITIONS':{'species':species, 'wickoffs':wyck,'positions':positions},'unit':'crystal_sg'}
        atposkeys = ['species', 'wickoffs','positions']
        kpoints = {'K_POINTS':{'kpoints':kpt+kpt_offset},'unit':'automatic'}
        kptkeys = ['kpoints']
        
        qeInput = ''

        qeInput += makeNamelist('&CONTROL',control)
        qeInput += makeNamelist( '&SYSTEM' ,system,syskeys)
        qeInput += makeNamelist( '&ELECTRONS',electrons)
        qeInput += makeCard(atomic_sp,cardKeys = atspkeys,optionKey = optionkey,T = True) 
        qeInput += makeCard(atomic_pos,cardKeys = atposkeys,optionKey = optionkey,T = True) 
        qeInput += makeCard(kpoints,cardKeys = kptkeys,optionKey = optionkey,T = False)
        
        inputDic[SpaceGroupIdx] = qeInput
        
    return inputDic

# %% [markdown]
# ## Load general information

# %%
fileNames = {}
dataDir = '../'
fileNames['crystals'] = 'Si-crystals-full-relax.pck'
fileNames['wyck'] = dataDir+'SpaceGroup-multiplicity-wickoff-info.pck'
fileNames['general info'] = dataDir+'SpaceGroup-general-info.pck'
fileNames['elements info'] = dataDir+'General-Info-Elements-fast.pck'

# %%
# give the SG 
spaceGroupIdxRange  = range(1,230+1)

Gen  = GenCrystalStructures(spaceGroupIdxRange=spaceGroupIdxRange)
Gen.setCrystals(fileNames['crystals'])
with open(fileNames['wyck'],'rb') as f:
    WyckTable = pck.load(f)
SGTable = pd.read_pickle(fileNames['general info'])
ElemTable = pd.read_pickle(fileNames['elements info'])

# %%
crystals = Gen.crystals

# %%
pck.dump?

# %%
with open('230spg-crystals.pck','wb') as f:
    pck.dump(crystals,f)

# %%
inputDic = makeQEInnput(Gen.crystals,WyckTable,SGTable,ElemTable)

# %%
print inputDic[50]
# Out:
# &CONTROL
#   wf_collect = .false.
#   calculation = "scf"
#   verbosity = "high"
#   pseudo_dir = "./pseudo"
#   prefix = "qe"
#   restart_mode = "from_scratch"
#   outdir = "./out/"
# /
# &SYSTEM
#   ecutrho = 80.00000
#   ecutwfc = 20.00000
#   ibrav = 8
#   nat = 1
#   nbnd = 20
#   ntyp = 1
#   occupations = "smearing"
#   smearing = "cold"
#   degauss = 1.0000000000d-02
#   space_group = 50
#   A = 3.40012493343
#   B = 5.05457258726
#   C = 9.02605614869
#   cosAB = 0.00000
#   cosAC = -0.00000
#   cosBC = 0.00000
# /
# &ELECTRONS
#   conv_thr = 1.0000000000d-06
# /
# ATOMIC_SPECIES
#   Si  28.0855  Si.pbe-n-rrkjus_psl.1.0.0.UPF
# ATOMIC_POSITIONS  crystal_sg
#   Si  8m   0.75000817  0.87506799  0.59441631
# K_POINTS  automatic
#   2  2  2  0  0  0

# %%
def make_dir(file_path):
    directory = os.path.abspath(file_path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
#'/Users/iMac/Documents/Workdir/QMAT/check-QE-crystal_sg'
dirNames = {sg:'./data/sg-test_'+str(sg) for sg in range(1,230+1)}

# %%
import subprocess as sp
os.environ['TMPDIR'] = "/tmp/"

# %%
exitState = {}
for sg in dirNames:
    make_dir(dirNames[sg])
    inputName = os.path.abspath(dirNames[sg]+'/qe.in')
    outputName = os.path.abspath(dirNames[sg]+'/qe.out')
    errName = os.path.abspath(dirNames[sg]+'/qe.err')
    with open(inputName,'w') as f:
        f.write(inputDic[sg])
    param = '-in '+ inputName
    print param
    # Set up the echo command and direct the output to a pipe
    exitState[sg] = sp.call('mpirun -np 2 pw.x ' + param , stdout=open(outputName, 'w'), 
                             stderr=open(errName, 'w'), shell=True)
    if exitState[sg]:
        print sg
# Out:
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_1/qe.in
# 1
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_2/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_3/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_4/qe.in
# 4
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_5/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_6/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_7/qe.in
# 7
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_8/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_9/qe.in
# 9
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_10/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_11/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_12/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_13/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_14/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_15/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_16/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_17/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_18/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_19/qe.in
# 19
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_20/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_21/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_22/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_23/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_24/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_25/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_26/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_27/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_28/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_29/qe.in
# 29
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_30/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_31/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_32/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_33/qe.in
# 33
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_34/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_35/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_36/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_37/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_38/qe.in
# 38
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_39/qe.in
# 39
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_40/qe.in
# 40
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_41/qe.in
# 41
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_42/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_43/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_44/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_45/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_46/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_47/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_48/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_49/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_50/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_51/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_52/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_53/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_54/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_55/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_56/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_57/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_58/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_59/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_60/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_61/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_62/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_63/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_64/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_65/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_66/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_67/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_68/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_69/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_70/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_71/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_72/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_73/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_74/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_75/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_76/qe.in
# 76
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_77/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_78/qe.in
# 78
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_79/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_80/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_81/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_82/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_83/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_84/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_85/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_86/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_87/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_88/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_89/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_90/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_91/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_92/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_93/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_94/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_95/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_96/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_97/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_98/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_99/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_100/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_101/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_102/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_103/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_104/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_105/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_106/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_107/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_108/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_109/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_110/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_111/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_112/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_113/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_114/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_115/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_116/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_117/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_118/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_119/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_120/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_121/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_122/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_123/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_124/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_125/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_126/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_127/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_128/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_129/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_130/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_131/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_132/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_133/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_134/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_135/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_136/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_137/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_138/qe.in
# 138
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_139/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_140/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_141/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_142/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_143/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_144/qe.in
# 144
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_145/qe.in
# 145
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_146/qe.in
# 146
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_147/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_148/qe.in
# 148
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_149/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_150/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_151/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_152/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_153/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_154/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_155/qe.in
# 155
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_156/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_157/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_158/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_159/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_160/qe.in
# 160
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_161/qe.in
# 161
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_162/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_163/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_164/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_165/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_166/qe.in
# 166
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_167/qe.in
# 167
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_168/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_169/qe.in
# 169
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_170/qe.in
# 170
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_171/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_172/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_173/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_174/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_175/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_176/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_177/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_178/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_179/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_180/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_181/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_182/qe.in
# 182
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_183/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_184/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_185/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_186/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_187/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_188/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_189/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_190/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_191/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_192/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_193/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_194/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_195/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_196/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_197/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_198/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_199/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_200/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_201/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_202/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_203/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_204/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_205/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_206/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_207/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_208/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_209/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_210/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_211/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_212/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_213/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_214/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_215/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_216/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_217/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_218/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_219/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_220/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_221/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_222/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_223/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_224/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_225/qe.in
# 225
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_226/qe.in
# 226
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_227/qe.in
# 227
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_228/qe.in
# 228
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_229/qe.in
# -in /Users/iMac/Dropbox/Felix_work/qmat/qe-sg-detection-test/sg_230/qe.in

# %%
prbSg = []
for sg in exitState:
    if exitState[sg]:
        prbSg.append(sg)

# %%
print prbSg
# Out:
# [1, 4, 7, 9, 19, 29, 33, 38, 39, 40, 41, 76, 78, 138, 144, 145, 146, 148, 155, 160, 161, 166, 167, 169, 170, 182, 225, 226, 227, 228]
